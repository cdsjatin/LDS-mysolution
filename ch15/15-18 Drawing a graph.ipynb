# %% [markdown]
# ### 15-18 Drawing a graph
#
# READ Q FROM QUESTIONAIRE

# %% [markdown]
# ### (A)

# %%
import scipy.io as sio

# %%
mat_content = sio.loadmat('octave_dg_data.mat')

# %%
print(mat_content.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'A', 'm', 'n', 'x_circ', 'y_circ'])

# %%
A = mat_content['A']
m = mat_content['m']
n = mat_content['n']
x = mat_content['x_circ']
y = mat_content['y_circ']
print(A.shape)
print(x.shape)
print(y.shape)
# Out:
# (60, 60)
# (60, 1)
# (60, 1)

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
print(type(A))
# Out:
# <class 'numpy.ndarray'>

# %%
G = nx.from_numpy_array(A)
nx.draw_networkx(G, with_labels=True)

# %%
pos = {i:np.asarray([*x,*y_circ[i]]) for i,x in enumerate(x_circ)}

# %%
plt.figure(figsize=(10,10))
nx.draw_networkx(G, pos=pos, with_labels=True)

# %%
# Spectral will give the minimum value for the graph.
pos = nx.draw_spectral(G, with_labels=True)

# %%
plt.figure(figsize=(10,10))
nx.draw_circular(G, with_labels=True)
